# %% [markdown]
# # Figures for Full Report

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import sys
import os
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
import seaborn as sns
sns.set(rc={"figure.figsize": (20, 18), "lines.linewidth": 5})
sns.set_style("darkgrid")

sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/"
                   "visualize/Total_Costs/Total_Costs_by_Type")
sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Dashboard/"
                   "carceral_budgeting_app/Apps")
sys.path.insert(0, "Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/"
                   "Full_Project_Reportback")

from Total_Costs_by_Type_2Ver import by_type
import app_helpers
from Full_Project_Reportback_1Ver import plot_over_time

# %%
yr = list(range(2016,2020))

# %%
overall, by_agency = by_type()

# %%
by_agency = app_helpers.prep_by_agency(by_agency)

# %%
spending_by_agency = by_agency.groupby("Nice Name").sum()[yr].reset_index()

# %%
spending_by_agency_melted = spending_by_agency.melt(id_vars=["Nice Name"])
spending_by_agency_melted
# Out:
#                                 Nice Name variable         value
# 0                           Appeals Court     2016   1535674.777
# 1                               Boston PD     2016 559141507.239
# 2                              Chelsea PD     2016  12663032.759
# 3   Committee for Public Counsel Services     2016  11485840.394
# 4                Department of Correction     2016 107294040.601
# ..                                    ...      ...           ...
# 63                 Suffolk County Sheriff     2019 142561182.680
# 64              Suffolk District Attorney     2019  29094314.634
# 65                 Supreme Judicial Court     2019   2157771.284
# 66                            Trial Court     2019  49512399.802
# 67                            Winthrop PD     2019   5975583.786
#
# [68 rows x 3 columns]

# %%
spending_all = plot_over_time(spending_by_agency, "Spending by All Agencies", hue_tup=("Nice Name", "Agency"))

# %%
spending_all.savefig('Figures/spending_all.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-d510d63b1412> in <module>
# ----> 1 spending_all.savefig('Figures/spending_all.png')
#
# AttributeError: 'NoneType' object has no attribute 'savefig'
