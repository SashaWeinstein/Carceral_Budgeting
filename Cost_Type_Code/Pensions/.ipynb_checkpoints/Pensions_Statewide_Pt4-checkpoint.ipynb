# %% [markdown]
# Created this notebook to find supreme judicial court, appeals court pensions

# %%
import pandas as pd
import State_Pensions_2Ver
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
pensions = State_Pensions_2Ver.get_cthru_pension_payouts(False)
# Out:
# found df
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/pensions/State_Pensions_2Ver.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
pensions.head(5)
# Out:
#    Unnamed: 0   trans_no   last_name first_name       date_of_retirement  \
# 0           0  S00000910         Cox      David  2003-10-01T00:00:00.000
# 1           1  S00001339    Lee, Jr.     Thomas  2015-06-30T00:00:00.000
# 2           2  S00003003       Gomes     Robert  1992-07-01T00:00:00.000
# 3           3  S00000390  Montecalvo     Marion  1998-10-05T00:00:00.000
# 4           4  S00000715        Bodo     Gloria  1984-01-28T00:00:00.000
#
#   title_at_retirement                      department  monthly_amount  year  \
# 0  Administrator Viii        Tewksbury State Hospital        4807.880  2016
# 1   Fiscal Officer vi        Commission For The Blind        5258.980  2016
# 2                None     Procurement & Gen. Services        1974.270  2016
# 3                None    Dept. Of Children & Families        1122.850  2016
# 4                None  Budget Bureau, Central Bus.off        2310.120  2016
#
# ...

# %%
pd.set_option("display.max.rows", 642)
pensions[pensions["department"].str.contains("Court")].groupby("department").sum()["annual_amount"].sort_values(ascending=False)
# Out:
# department
# Trial Court Justice              138307164.840
# Admin.office/district Court       77291691.600
# Office Of Court Management        31166425.320
# Boston Municipal Court            21409610.640
# Appeals CourT-John Adams Court    21231043.080
# Trial Court Administration        18976904.640
# Supreme Judicial Court            13596246.240
# Juvenile Court Administration     12687665.520
# General Court                      8122587.600
# Superior Court Probation           7353044.760
# Boston Housing Court               5582376.960
# Land Court                         5515315.800
# Trial Court Law Libraries          5236149.240
# Suffolk Superior Court Civil       4451060.280
# Roxbury District Court             4244253.480
# East Norfolk District Court        4076359.080
# Central Worcester Dist. Court      4026768.840
# Springfield District Court         3880312.440
# Suffolk Probate & Family Court     3743597.040
# Suffolk Cty. Juvenile Court        3294656.040
# ...
