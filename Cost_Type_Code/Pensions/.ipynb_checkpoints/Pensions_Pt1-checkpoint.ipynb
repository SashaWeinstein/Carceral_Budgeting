# %% [markdown]
# # Pensions
#
# First question to ask: does the spending dataset include payments to massachusetts pension fund?

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from sodapy import Socrata
app_token = "2Qa1WiG8G4kj1vGVd2noK7zP0"
client = Socrata("cthru.data.socrata.com", app_token)
client.timeout = 40
import sys
import os
sys.path.insert(0, os.path.abspath('../'))
sys.path.insert(0, os.path.abspath('../..'))
import Initialize_Agencies

# %%
expenditures = client.get("pegc-naaa", where="Department = 'TRIAL COURT (TRC)' AND budget_fiscal_year >= 2016", limit=999999)

# %%
expenditures = pd.DataFrame(expenditures)

# %%
expenditures.head(5)
# Out:
#                 base_id budget_fiscal_year fiscal_period  \
# 0  A0000000001738866371               2020            11
# 1  A0000000001738867796               2020             4
# 2  A0000000001738867797               2020             6
# 3  A0000000001738867798               2020             7
# 4  A0000000001738867836               2020             4
#
#                       date cabinet_secretariat         department  \
# 0  2020-06-02T00:00:00.000           JUDICIARY  TRIAL COURT (TRC)
# 1  2019-11-01T00:00:00.000           JUDICIARY  TRIAL COURT (TRC)
# 2  2019-12-23T00:00:00.000           JUDICIARY  TRIAL COURT (TRC)
# 3  2020-02-19T00:00:00.000           JUDICIARY  TRIAL COURT (TRC)
# 4  2019-11-01T00:00:00.000           JUDICIARY  TRIAL COURT (TRC)
#
#                           appropriation_type               appropriation_name  \
# 0  (1CS) DIRECT APPROPRIATIONS/SUBSIDIARIZED  (03300300) ADMINISTRATIVE STAFF
# ...

# %%
expenditures[expenditures["object_class"].str.contains("PENSION")]["amount"].astype(float).sum()
# Out:
# 34483372.010000005
