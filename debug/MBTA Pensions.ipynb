# %% [markdown]
# ## MBTA Pensions
# Last I checked there are very few employees with MBTA as thier employers in the pensions payout database. Triple check this before I implement a methodology where MBTA uses fraction of payroll to estimate pensions costs

# %%
import pandas as pd
from sodapy import Socrata
app_token = "2Qa1WiG8G4kj1vGVd2noK7zP0"
client = Socrata("cthru.data.socrata.com", app_token)
client.timeout = 40

# %%
pensions = pd.DataFrame(client.get("pni4-392n", where="Year >= 2016 AND Year <= 2019", limit =999999))

# %%
pensions = pensions[pensions["department_last_worked_in"].isna()==False]

# %%
mDOT_pensions = pensions[(pensions["department_last_worked_in"].str.contains("(?i)transportation"))|
                        (pensions["department_last_worked_in"].str.contains("(?i)transit"))]

# %%
mDOT_pensions[mDOT_pensions["title_at_retirement"].str.contains("(?i)police")]
# Out:
#          trans_no last_name   first_name       date_of_retirement  \
# 37635   S03461198  Pembroke        Denis  2010-02-12T00:00:00.000
# 46068   S06507553   Sellers      Francis  2011-09-11T00:00:00.000
# 107537  S04339738    Martin  Christopher  2010-02-16T00:00:00.000
# 124666  S00413543   Eiseman       Robert  2009-12-31T00:00:00.000
# 168281  S06507553   Sellers      Francis  2011-09-11T00:00:00.000
# 168298  S06508931   Mcnealy         Paul  2016-12-30T00:00:00.000
# 277101  S00413543   Eiseman       Robert  2009-12-31T00:00:00.000
# 325333  S06508931   Mcnealy         Paul  2016-12-30T00:00:00.000
# 355998  S06507553   Sellers      Francis  2011-09-11T00:00:00.000
# 431546  S06507553   Sellers      Francis  2011-09-11T00:00:00.000
# 450371  S00413543   Eiseman       Robert  2009-12-31T00:00:00.000
# 484185  S06508931   Mcnealy         Paul  2016-12-30T00:00:00.000
#
#                    title_at_retirement    department_last_worked_in  \
# ...
