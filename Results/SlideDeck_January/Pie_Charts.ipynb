# %% [markdown]
# # Costs By Agency, Cost Type

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Visualize/")
from Pie import Agency_Costs_Pie, Cost_Types_Pie, Category_Pie

# %% [markdown]
# ## By Agency

# %%
agency_costs_pie = Agency_Costs_Pie(9, "Average Cost per Year")
agency_costs_pie.savefig("Costs_By_Agency_Pie.png")
# Out:
# the top  9 agencies account for  0.9811744766913661 of total cost

# %% [markdown]
# ## By Cost Type

# %%
cost_types_pie = Cost_Types_Pie( "Cost Types")
cost_types_pie.savefig("Cost_Types_Pie_Jan12.png")

# %% [markdown]
# ## By Category

# %%
category_pie = Category_Pie("Category")
category_pie.savefig("Category_Pie_Jan12.png")
# Out:
# Category
# Police    6.910740e+08
# Jails     2.759556e+08
# Legal     9.210172e+07
# dtype: float64

# %%
category_mean = pd.read_csv("../../Final_Results/Final_by_Category.csv")\
    .set_index("Category").mean(axis=1).sort_values(ascending=False)

# %%
category_mean.loc["Police"]/10**6
# Out:
# 691.0740390560412

# %%
category_mean.loc["Legal"]/10**6
# Out:
# 92.10171697158376

# %%
category_mean.loc["Jails"]/10**6
# Out:
# 275.9556277113952

# %%
category_mean/category_mean.sum()
# Out:
# Category
# Police    0.652491
# Jails     0.260549
# Legal     0.086960
# dtype: float64
