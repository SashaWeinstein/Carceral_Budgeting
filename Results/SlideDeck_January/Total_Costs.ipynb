# %% [markdown]
# # Total Costs

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Visualize/")
from Costs_Over_Time import Total_Cost_By_Year

# %% [markdown]
# ## Load in Data

# %%
total_costs = pd.read_csv("../../Final_Results/Final_by_Year.csv").set_index("Year").squeeze()

# %%
total_costs.mean() / 10**9
# Out:
# 1.0591313837390202

# %%
p = Total_Cost_By_Year(total_costs, "", 48, (25, 15), False)

# %%
p.savefig("Total_Cost_By_Year_Jan12.png")
