# %% [markdown]
# # Total Costs

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Visualize/")
from Costs_Over_Time import Total_Cost_By_Year, Total_Costs_by_Year_splitHidden

# %% [markdown]
# ## Load in Data

# %%
total_costs = pd.read_csv("../../Final_Results/Final_by_Year.csv").set_index("Year").squeeze()

# %%
total_costs.mean() / 10**9
# Out:
# 1.0506457869982122

# %%
p = Total_Cost_By_Year(total_costs, "", 48, (25, 15), False)

# %%
p.savefig("Total_Cost_By_Year_Jan12.png")

# %% [markdown]
# ## Answer question: how much does yearly average increase when considering hidden costs?

# %%
sys.path.insert(0, "../../Final_Results")
from Final_Results_Helpers import get_Result
by_year_SH = get_Result("Final_by_Year_splitHidden.csv")

# %%
by_year_SH_mean = by_year_SH.mean(axis=1)

# %%
by_year_SH_mean.loc["Total"] = by_year_SH_mean.sum()
by_year_SH_mean.values
# Out:
# array([7.00568806e+08, 3.50076981e+08, 1.05064579e+09])

# %% [markdown]
# ## Add cases on second axis

# %%
sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Misc_Analyses/")
from Efficiency_Metrics import SCDAO_cases

# %%
SCDAO_cases
# Out:
# 2016    30765.0
# 2017    28264.0
# 2018    27818.0
# 2019    26576.0
# dtype: float64

# %%
p = Total_Cost_By_Year(total_costs, "Criminal Legal System Costs Compared to SCDAO Cases", 48, (25, 15), False, SCDAO_cases)
p.savefig("Cost_per_Year_with_Cases.png", bbox_inches='tight')

# %% [markdown]
# ## For slide 11: stated versus total costs per year

# %%
byYear_SH = Total_Costs_by_Year_splitHidden()
# Out:
# fraction of total spending  that is stated 0.6667982824879308

# %%
byYear_SH.savefig("Cost_per_Year_splitHidden.png")

# %% [markdown]
# ## Compare to state+local spending

# %%
sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Misc_Analyses/Fraction_Total_Costs/")
from Serve_Total_Costs import MA_expend, Boston_citywide_expend, Revere_citywide_expend, Chelsea_citywide_expend, \
    Winthrop_citywide_expend
sys.path.insert(0, "../../Agency_Corrections")
from Agency_Corrections import population_correction

# %%
suff_expend = population_correction(MA_expend)

denominator = suff_expend + Boston_citywide_expend + Chelsea_citywide_expend + Revere_citywide_expend + \
              Winthrop_citywide_expend

# %%
denominator.to_csv("Total_State_Local_Spending_including_NonCarceral.csv")

# %%
denominator[2019]/denominator[2016]
# Out:
# 1.1420986427440145

# %%
total_costs[2019]/total_costs[2016]
# Out:
# 1.1437055625960728
