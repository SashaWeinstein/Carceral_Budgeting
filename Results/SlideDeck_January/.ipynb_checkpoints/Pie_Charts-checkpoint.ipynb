# %% [markdown]
# # Costs By Agency, Cost Type

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt
import palettable

# %%
sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Visualize/")
from Pie import Agency_Costs_Pie, Cost_Types_Pie, Category_Pie, Cost_Types_splitPayroll_Pie
# Out:
#                   2016          2017          2018          2019
# Category
# Jails     2.674514e+08  2.590778e+08  2.817115e+08  2.955818e+08
# Legal     8.105425e+07  7.915242e+07  8.497993e+07  8.927788e+07
# Police    6.325372e+08  6.715407e+08  7.230539e+08  7.371644e+08

# %% [markdown]
# ## By Agency

# %%
s = pd.Series(index =["a","b", "c"], data = range(3))
[print(x, y) for x, y in s.iteritems()]
s.shape
# Out:
# a 0
# b 1
# c 2
# (3,)

# %%
agency_costs_pie = Agency_Costs_Pie(8, "Criminal Legal System Spending Yearly Average 2016-2019\nBroken Down by Agency")
agency_costs_pie.savefig("Costs_By_Agency_Pie.png")
# Out:
# the top  8 agencies account for  0.9773037804500072 of total cost

# %% [markdown]
# ## By Cost Type

# %%
cost_types_pie = Cost_Types_Pie("Criminal Legal System Spending Yearly Average 2016-2019\nBroken Down by Cost Type")
cost_types_pie.savefig("Cost_Types_Pie_Jan12.png")
# Out:
# Payroll ($670.8 million)                 6.708047e+08
# Fringe Benefits ($149.3 million)         1.493202e+08
# Pensions ($130.6 million)                1.306270e+08
# Non-Payroll Operating ($85.5 million)    8.550526e+07
# Capital ($22.9 million)                  2.287422e+07
# dtype: float64

# %% [markdown]
# ## By Category

# %%
category_pie = Category_Pie("Criminal Legal System Spending Yearly Average 2016-2019\nBroken Down by Category")
category_pie.savefig("Category_Pie_Jan12.png")
# Out:
# Category
# Police    6.910740e+08
# Jails     2.759556e+08
# Legal     8.361612e+07
# dtype: float64
# Police ($691.1 million)    6.910740e+08
# Jails ($276.0 million)     2.759556e+08
# Legal ($83.6 million)      8.361612e+07
# dtype: float64

# %% [markdown]
# ## By Cost Type Split Payroll

# %%
SP_pie = Cost_Types_splitPayroll_Pie("Cost Type")
SP_pie.savefig("Cost_Type_SP_Pie_Jan14.png")
# Out:
# reminder: pair colors for both payrolls and outline stated costs
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-43-7d42b32279ff> in <module>
# ----> 1 SP_pie = Cost_Types_splitPayroll_Pie("Cost Type")
#       2 SP_pie.savefig("Cost_Type_SP_Pie_Jan14.png")
#
# ~/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Visualize/Pie.py in Cost_Types_splitPayroll_Pie(title)
#      69     return Generate_Pie(cost_types_SP_mean, 6, title,
#      70                         palettable.tableau.GreenOrange_12.mpl_colors[:2] +
# ---> 71                         palettable.tableau.GreenOrange_6.mpl_colors[1:])
#
# ~/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Visualize/Pie.py in Generate_Pie(full_costs, num_wedges, title, pal)
#      26         costs = full_costs.iloc[:num_wedges, ]
# ...

# %%
from Pie import cost_types_SP_mean
cost_types_SP_mean.loc["Hidden Payroll Costs"]
# Out:
# 64311913.065774955
