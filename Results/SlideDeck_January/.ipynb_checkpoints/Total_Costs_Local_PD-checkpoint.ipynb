# %% [markdown]
# # Total Costs of Local PD
# Need line chart of 2016-2019 total costs of local PD

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.insert(0, "/Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Visualize/")
from Costs_Over_Time import Total_Cost_By_Year

# %%
sns.set(rc={"figure.figsize": (20, 18), "lines.linewidth": 5})
sns.set_style("darkgrid")

# %% [markdown]
# ## Load in Data

# %%
by_agency = pd.read_csv("../../Final_Results/Final_by_Agency.csv", index_col = 0)

# %%
localPD = by_agency.loc[["Boston PD", "Chelsea PD", "Revere PD", "Winthrop PD"]].sum()

# %%
p = Total_Cost_By_Year(localPD)
