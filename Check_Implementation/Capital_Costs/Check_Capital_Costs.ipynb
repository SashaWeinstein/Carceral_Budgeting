# %% [markdown]
# # Capital Costs
# Should be a fairly simple check.
#
# 1. Need to go through DCP to make sure I got all carceral agencies
# 2. Need to make sure capital costs are taken out of expenditures record and put into correct agency
# 3. Check each police department.

# %% [markdown]
# ## Set up environment

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import os
import sys
import numpy as np
from sodapy import Socrata

# %%
sys.path.insert(0, os.path.abspath("../.."))

# %%
app_token = "2Qa1WiG8G4kj1vGVd2noK7zP0"
client = Socrata("cthru.data.socrata.com", app_token)
client.timeout = 40

# %%
from Initialize_Agencies_3Ver import get_agencies
yr = list(range(2016,2020))
agencies = get_agencies(yr)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/pensions/State_Pensions_2Ver.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cthru_pensions["year"] = cthru_pensions["year"].astype(int)
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Initialize_Agencies_3Ver.py:5: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   from Agency_Classes_2Ver import StateAgency, CPCS, MBTA, BostonPD, ChelseaPD, ReverePD, WinthropPD
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Agency_Classes_2Ver.py:184: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.get_expenditures_by_year()
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Agency_Classes_2Ver.py:178: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.get_final_costs()
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Agency_Classes_2Ver.py:184: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.get_expenditures_by_year()
# winthrop pensions/benefits are
#                                 2016     2017     2018     2019
# Fringe Benefit Expenditures  2389319  3530628  3306194  3328702
# Pension Expenditures         2741050  2087906  2222798  2232037

# %% [markdown]
# ## Get statewide capital expenditures through DCP

# %%
DCP = pd.DataFrame(client.get("pegc-naaa",
                where="department ='CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVISION (DCP)'"+ \
                "AND budget_fiscal_year >= 2016"))
DCP
# Out:
#                   base_id budget_fiscal_year fiscal_period  \
# 0    A0000000000976389201               2018             8
# 1    A0000000000976389738               2018             8
# 2    A0000000000976390694               2018             9
# 3    A0000000000976391291               2018             8
# 4    A0000000000976391307               2018             8
# ..                    ...                ...           ...
# 995  A0000000000977355382               2017            12
# 996  A0000000000977355405               2018            11
# 997  A0000000000977356884               2016            10
# 998  A0000000000977364795               2018             5
# 999  A0000000000977366667               2018             3
#
#                         date                           cabinet_secretariat  \
# 0    2018-02-16T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# 1    2018-02-12T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# 2    2018-08-13T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# 3    2018-03-07T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# 4    2018-03-09T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# ..                       ...                                           ...
# 995  2017-07-06T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# 996  2018-05-18T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# 997  2016-04-27T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# 998  2017-12-15T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
# 999  2017-09-29T00:00:00.000  EXECUTIVE OFFICE FOR ADMINSTRATION & FINANCE
#
#                                             department  \
# 0    CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# 1    CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# 2    CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# 3    CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# 4    CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# ..                                                 ...
# 995  CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# 996  CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# 997  CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# 998  CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
# 999  CAPITAL ASSET MANAGEMENT AND MAINTENANCE DIVIS...
#
#                            appropriation_type  \
# 0                               (2CN) CAPITAL
# 1    (1RN) RETAINED REVENUE/NON-SUBSIDIARIZED
# 2                                (3TN) TRUSTS
# 3                               (2CN) CAPITAL
# 4                               (2CN) CAPITAL
# ..                                        ...
# 995                             (2CN) CAPITAL
# 996                              (3TN) TRUSTS
# 997                              (3TN) TRUSTS
# 998                              (3TN) TRUSTS
# 999                             (2CN) CAPITAL
#
#                                     appropriation_name  \
# 0          (89008500) JAIL AND CORRECTIONAL FACILITIES
# 1      (11023205) MASSACHUSETTS INFORMATION TECHNOLOGY
# 2                      (61070520) WT OPERATING ACCOUNT
# 3        (11022009) COMMONWEALTH FACILITY IMPROVEMENTS
# 4        (71001000) UMASS CAMPUS FACILITY IMPROVEMENTS
# ..                                                 ...
# 995      (11022009) COMMONWEALTH FACILITY IMPROVEMENTS
# 996  (11022494) FORWARD CAPACITY MARKET AND ENERGY ...
# 997         (11021113) SALEM STATE THEATRE RENOVATIONS
# 998  (11022494) FORWARD CAPACITY MARKET AND ENERGY ...
# 999      (11022009) COMMONWEALTH FACILITY IMPROVEMENTS
#
#                            object_class  \
# 0          (EE) ADMINISTRATIVE EXPENSES
# 1                  (NN) INFRASTRUCTURE:
# 2          (EE) ADMINISTRATIVE EXPENSES
# 3                  (NN) INFRASTRUCTURE:
# 4                  (NN) INFRASTRUCTURE:
# ..                                  ...
# 995                (NN) INFRASTRUCTURE:
# 996  (GG) ENERGY COSTS AND SPACE RENTAL
# 997                (NN) INFRASTRUCTURE:
# 998  (GG) ENERGY COSTS AND SPACE RENTAL
# 999                (NN) INFRASTRUCTURE:
#
#                                            object_code  ...  \
# 0                              (E14) EXHIBITS/DISPLAYS  ...
# 1       (N74) SNOW REMOVAL AND GROUNDSKEEPING SERVICES  ...
# 2                              (E14) EXHIBITS/DISPLAYS  ...
# 3    (NN1) ENGINEERING, RESEARCH AND SCIENTIFIC SER...  ...
# 4    (NN1) ENGINEERING, RESEARCH AND SCIENTIFIC SER...  ...
# ..                                                 ...  ...
# 995  (NN1) ENGINEERING, RESEARCH AND SCIENTIFIC SER...  ...
# 996                               (G10) ENERGY SAVINGS  ...
# 997  (NN1) ENGINEERING, RESEARCH AND SCIENTIFIC SER...  ...
# 998                               (G10) ENERGY SAVINGS  ...
# 999  (NN1) ENGINEERING, RESEARCH AND SCIENTIFIC SER...  ...
#
#     appropriation_code object department_code  \
# 0             89008500    E14             DCP
# 1             11023205    N74             DCP
# 2             61070520    E14             DCP
# 3             11022009    NN1             DCP
# 4             71001000    NN1             DCP
# ..                 ...    ...             ...
# 995           11022009    NN1             DCP
# 996           11022494    G10             DCP
# 997           11021113    NN1             DCP
# 998           11022494    G10             DCP
# 999           11022009    NN1             DCP
#
#                                    vendor                vendor_id  \
# 0                        CHRISTINE MILLER        OCEANS PROMOTIONS
# 1                   J MARCHESE & SONS INC               UNASSIGNED
# 2       NEW ENGLAND ART ED CONFERENCE INC               UNASSIGNED
# 3             LEERS WEINZAPFEL ASSOCS INC  ANDREA LEERS ASSOCS INC
# 4                  WILSON ARCHITECTS INC.               UNASSIGNED
# ..                                    ...                      ...
# 995           LEERS WEINZAPFEL ASSOCS INC  ANDREA LEERS ASSOCS INC
# 996               ENERGY CONSERVATION INC               UNASSIGNED
# 997           LEERS WEINZAPFEL ASSOCS INC  ANDREA LEERS ASSOCS INC
# 998  GUARDIAN ENERGY MANAGEMENT SOLUTIONS               UNASSIGNED
# 999                   CDW CONSULTANTS INC               UNASSIGNED
#
#                payment_id payment_method       state          city  \
# 0    INTFINV0000000093352            EFT  UNASSIGNED    UNASSIGNED
# 1    02081800000000070745            EFT          MA       EVERETT
# 2    03071800000000079950          CHECK          MA  PROVINCETOWN
# 3    INTFINV0000000093386            EFT          MA        BOSTON
# 4    INTFINV0000000093448            EFT          MA        BOSTON
# ..                    ...            ...         ...           ...
# 995  INTFINV0000000089134            EFT          MA        BOSTON
# 996  INTFINV0000000094207            EFT          MA        HANSON
# 997  INTFINV0000000076294            EFT          MA        BOSTON
# 998  INTFINV0000000092245            EFT          MA   MARLBOROUGH
# 999  INTFINV0000000091488            EFT          MA        NATICK
#
#                  create_date
# 0    2019-08-31T13:32:03.000
# 1    2019-08-31T13:32:03.000
# 2    2019-08-31T13:32:03.000
# 3    2019-08-31T13:32:03.000
# 4    2019-08-31T13:32:03.000
# ..                       ...
# 995  2019-08-31T13:32:03.000
# 996  2019-08-31T13:32:03.000
# 997  2019-08-31T13:32:03.000
# 998  2019-08-31T13:32:03.000
# 999  2019-08-31T13:32:03.000
#
# [1000 rows x 25 columns]
