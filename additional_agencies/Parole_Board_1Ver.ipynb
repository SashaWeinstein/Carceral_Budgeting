# %% [markdown]
# The budget info on mass.gov seems to indicate that the parole board is a separtely funded agency within the state government. This notebook is to see if it is and what sort of spending seems to be listed under it

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from sodapy import Socrata
app_token = "2Qa1WiG8G4kj1vGVd2noK7zP0"
client = Socrata("cthru.data.socrata.com", app_token)
client.timeout = 40
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
def amount_to_float(df):
    df.loc[:,"amount"] = df.loc[:,"amount"].astype(float)
    return df

# %%
parole = pd.DataFrame(client.get("pegc-naaa", where = "Department = 'PAROLE BOARD (PAR)'\
                                                       AND budget_fiscal_year = 2019",
                                limit = 999999))

# %%
parole = amount_to_float(parole)

# %%
parole["amount"].sum()
# Out:
# 18238657.72

# %%
parole.head(5)
# Out:
#                 base_id budget_fiscal_year fiscal_period  \
# 0  A0000000001830667115               2019             8
# 1  A0000000001830790101               2019            10
# 2  A0000000001830859525               2019             3
# 3  A0000000001831119241               2019             7
# 4  A0000000001831174750               2019             3
#
#                       date                                cabinet_secretariat  \
# 0  2019-02-11T00:00:00.000  EXECUTIVE OFFICE OF PUBLIC SAFETY & HOMELAND S...
# 1  2019-04-16T00:00:00.000  EXECUTIVE OFFICE OF PUBLIC SAFETY & HOMELAND S...
# 2  2018-09-19T00:00:00.000  EXECUTIVE OFFICE OF PUBLIC SAFETY & HOMELAND S...
# 3  2019-01-15T00:00:00.000  EXECUTIVE OFFICE OF PUBLIC SAFETY & HOMELAND S...
# 4  2018-09-20T00:00:00.000  EXECUTIVE OFFICE OF PUBLIC SAFETY & HOMELAND S...
#
#            department                         appropriation_type  \
# 0  PAROLE BOARD (PAR)  (1CS) DIRECT APPROPRIATIONS/SUBSIDIARIZED
# ...

# %% [markdown]
# Ok, I should add parole board as another agency
