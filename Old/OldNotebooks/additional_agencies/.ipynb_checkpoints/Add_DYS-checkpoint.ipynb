# %% [markdown]
# # Add DYS
# Make sure adding DYS goes smoothly

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import os
import sys
import numpy as np

# %%
sys.path.insert(0, os.path.abspath("../../"))
sys.path.insert(0, os.path.abspath("../../Final_Results"))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Cost_Type_Code/Pensions/Statewide_Pensions.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from Initialize_Agencies import get_agencies
yr = list(range(2016,2020))
agencies = get_agencies(yr)
# Out:
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Agency_Classes/State_Agency.py:59: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.get_expenditures_by_year()
# agencies with pension dollars in Pensions_Final.py
# Index(['Appeals_Court', 'CPCS', 'DAA', 'DYS', 'Parole_Board', 'State_Police',
#        'Suffolk_DA', 'Suffolk_Sheriff', 'Supreme_Judicial_Court',
#        'trial_court_local', 'trial_court_statewide', 'DOC'],
#       dtype='object', name='agency_class')
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Agency_Classes/State_Agency.py:59: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.get_expenditures_by_year()
# agencies with pension dollars in Pensions_Final.py
# Index(['Appeals_Court', 'CPCS', 'DAA', 'DYS', 'Parole_Board', 'State_Police',
# ...

# %%
DYS = agencies["DYS"]

# %%
# Out:
# {'alias': 'DYS',
#  'official_name': 'DEPARTMENT OF YOUTH SERVICES (DYS)',
#  'year_range': [2016, 2017, 2018, 2019],
#  'calender_year_data': False,
#  'requery': False,
#  'category': 'Jails',
#  'payroll_expenditures_by_year': budget_fiscal_year
#  2016   50315453.390
#  2017   53402494.060
#  2018   54061961.750
#  2019   56737244.300
#  Name: amount, dtype: float64,
#  'non_payroll_operating_expenditures_by_year': budget_fiscal_year
#  2016   93548875.260
#  2017   93010712.190
#  2018   89116368.580
#  2019   86137200.720
#  Name: amount, dtype: float64,
#  'correction_function': <function Agency_Corrections.population_correction(df)>,
#  'pensions': 2016   152045.898
#  2017    88516.806
#  2018    16744.091
#  2019    12642.876
#  Name: DYS, dtype: float64,
#  'payroll_by_year': 2016   50762395.645
#  2017   51584675.405
#  2018   53854380.375
#  2019   55168243.920
#  dtype: float64,
#  'local_pensions': 2016    0
#  2017    0
#  2018    0
#  2019    0
#  dtype: int64,
# ...

# %%
import Final_Results
# Out:
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Agency_Classes/State_Agency.py:59: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.get_expenditures_by_year()
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Agency_Classes/State_Agency.py:59: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.get_expenditures_by_year()
# /Users/alexanderweinstein/Documents/Harris/Summer2020/Carceral_Budgeting/Exploratory/Agency_Classes/State_Agency.py:59: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.get_expenditures_by_year()
# ...

# %%
final_by_agency_type_pre_correction = Final_Results.get_preCorrection_by_Agency_Type()

# %%
final_by_agency_type_pre_correction[final_by_agency_type_pre_correction["Agency"]=="DYS"]
# Out:
#                                 Agency Category               Cost Type  \
# DYS Payroll Costs                  DYS     Jails                Payroll
# DYS Non-Payroll Operating Costs    DYS     Jails  Non-Payroll Operating
# DYS Pension Costs                  DYS     Jails               Pensions
# DYS Fringe Benefit Costs           DYS     Jails        Fringe Benefits
# DYS Capital Costs                  DYS     Jails                Capital
#
#                                         2016         2017         2018  \
# DYS Payroll Costs               50762395.645 51584675.405 53854380.375
# DYS Non-Payroll Operating Costs 93548875.260 93010712.190 89116368.580
# DYS Pension Costs                 152045.898    88516.806    16744.091
# DYS Fringe Benefit Costs        20836383.373 20475924.129 19626422.074
# DYS Capital Costs                 279459.120  1282070.650  1056699.010
#
#                                         2019
# DYS Payroll Costs               55168243.920
# ...

# %%
by_agency = Final_Results.get_by_Agency()

# %% [markdown]
# How big is DYS relatively speaking?

# %%
by_agency.mean(axis=1).sort_values(ascending=False)
# Out:
# Agency
# Boston PD                  570030100.973
# Suffolk_Sheriff            138219144.777
# DOC                        133107920.017
# State_Police                72918343.511
# trial_court                 49210773.769
# Suffolk_DA                  26690238.001
# Revere PD                   20817788.748
# DYS                         18842031.402
# Chelsea PD                  15805789.751
# MBTA                         5470595.679
# Winthrop PD                  5233895.223
# Parole_Board                 4628562.917
# CPCS                         3906984.900
# Supreme_Judicial_Court       1879867.623
# Appeals_Court                1460691.137
# CJT                           749949.428
# DAA                           467564.801
# MA Sheriff's Association       47575.743
# dtype: float64
