# %% [markdown]
# # Total Costs by Type
# As of August 20th, each agency has the following 4 attributes: operating costs, pensions, fringe benefits, and capital expenditures. I'll call these cost "types" for this notebook. This notebook will take the total amount of money spent on each type and then maybe the total money spent on each by category (courts, jails, cops).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import sys
import os
import warnings
warnings.filterwarnings('ignore')
sys.path.insert(0, os.path.abspath('../..'))
import Agency_Classes
from Total_Costs_by_Type_1Ver import by_type

# %%
yr=list(range(2016,2020))
from Initialize_Agencies_2Ver import get_agencies
agencies = get_agencies(yr)
# Out:
# Note: corrections for Supreme Judicial Court, Appeals Court not finished yet. Currently using trial court correction
# data is
#                               2016     2017     2018   2019
# ReverePD Projects       102859.340   104200   101950  50000
# Public Safety Projects 1292643.740  1294156  1082010      0
# correction is  2016   0.476
# 2017   0.462
# 2018   0.461
# 2019   0.000
# dtype: float64

# %%
buggy_agency = by_type(agencies)
# Out:
# got to  trial_court
# operating costs are budget_fiscal_year
# 2016   29514808.022
# 2017   28587705.150
# 2018   31745509.552
# 2019   34555131.781
# dtype: float64
# pension costs are 2016   3894418.329
# 2017   4029926.018
# 2018   4609502.150
# 2019   5014950.330
# dtype: float64
# fringe costs are  2016   189414308.075
# 2017   185294803.278
# 2018   180684732.724
# 2019   179130498.877
# dtype: float64
# capital costs are 2016   4935236.085
# 2017   6111280.808
# 2018   4326164.991
# 2019   4175944.501
# dtype: float64
# got to  CPCS
# operating costs are budget_fiscal_year
# 2016   10473825.822
# 2017   10845110.109
# 2018   11810792.998
# 2019   12874064.955
# dtype: float64
# pension costs are 2016   138312.721
# 2017   151213.769
# 2018   183909.183
# 2019   209405.683
# dtype: float64
# fringe costs are  2016   17836843.072
# 2017   17229365.418
# 2018   16183746.776
# 2019   17837397.620
# dtype: float64
# capital costs are 2016   0.000
# 2017   0.000
# 2018   0.000
# 2019   0.000
# dtype: float64
# got to  DOC
# operating costs are budget_fiscal_year
# 2016   78803895.629
# 2017   82048107.123
# 2018   95994615.446
# 2019   92643812.846
# dtype: float64
# pension costs are 2016   2424301.589
# 2017   2551173.530
# 2018   3093929.824
# 2019   3007687.823
# dtype: float64
# fringe costs are  2016   158915288.905
# 2017   152803475.499
# 2018   147882579.824
# 2019   149222139.371
# dtype: float64
# capital costs are 2016   6744485.406
# 2017   5681616.832
# 2018   5755019.864
# 2019   7274648.230
# dtype: float64
# got to  Suffolk_DA
# operating costs are budget_fiscal_year
# 2016   18125340.410
# 2017   19009351.770
# 2018   18788998.570
# 2019   20935527.610
# Name: Total Expenditures, dtype: float64
# pension costs are 2016   1415752.247
# 2017   1541270.311
# 2018   1616475.447
# 2019   1835489.368
# Name: Suffolk_DA, dtype: float64
# fringe costs are  2016   6154286.152
# 2017   5929839.289
# 2018   5661537.900
# 2019   6323155.650
# dtype: float64
# capital costs are 2016    0
# 2017    0
# 2018    0
# 2019    0
# dtype: int64
# got to  Suffolk_Sheriff
# operating costs are budget_fiscal_year
# 2016   92214149.950
# 2017   91195516.680
# 2018   95322734.400
# 2019   99641993.430
# Name: Total Expenditures, dtype: float64
# pension costs are 2016   10420552.448
# 2017   11485910.768
# 2018   12362352.611
# 2019   13918561.350
# Name: Suffolk_Sheriff, dtype: float64
# fringe costs are  2016   31623728.367
# 2017   31106123.577
# 2018   29738744.661
# 2019   28906154.973
# dtype: float64
# capital costs are 2016   2286749.680
# 2017    749922.520
# 2018    893869.480
# 2019    375295.000
# dtype: float64
# got to  State_Police
# operating costs are budget_fiscal_year
# 2016   61983256.671
# 2017   61646345.569
# 2018   64539388.653
# 2019   67466621.319
# Name: Total Expenditures, dtype: float64
# pension costs are 2016   14175850.892
# 2017   15013172.616
# 2018   16545633.300
# 2019   18270371.950
# Name: State_Police, dtype: float64
# fringe costs are  2016   140491878.899
# 2017   140845831.668
# 2018   129152981.756
# 2019   124555328.502
# dtype: float64
# capital costs are 2016    8315793.260
# 2017    9844071.561
# 2018   10302822.350
# 2019   10714625.147
# dtype: float64
# got to  MBTA
# operating costs are year
# 2016   28140924.850
# 2017   22662116.390
# 2018   24217763.280
# 2019   31640635.490
# Name: police_pay, dtype: float64
# pension costs are 2016    0
# 2017    0
# 2018    0
# 2019    0
# dtype: int64
# fringe costs are  2016   10971998.712
# 2017    8466529.428
# 2018    8467111.261
# 2019   10745401.360
# dtype: float64
# capital costs are 2016    0
# 2017    0
# 2018    0
# 2019    0
# dtype: int64
# got to  DAA
# operating costs are budget_fiscal_year
# 2016   177113.095
# 2017   169767.654
# 2018   183427.160
# 2019   194995.527
# dtype: float64
# pension costs are 2016   3760.284
# 2017   3627.353
# 2018   5488.900
# 2019   5647.518
# dtype: float64
# fringe costs are  2016   391504.308
# 2017   389297.426
# 2018   372813.755
# 2019   376707.629
# dtype: float64
# capital costs are 2016   0.000
# 2017   0.000
# 2018   0.000
# 2019   0.000
# dtype: float64
# got to  MA Sheriff's Association
# operating costs are budget_fiscal_year
# 2016   17659.451
# 2017   15647.667
# 2018   16658.941
# 2019   18818.290
# dtype: float64
# pension costs are 2016   0.000
# 2017   0.000
# 2018   0.000
# 2019   0.000
# dtype: float64
# fringe costs are  year
# 2016   90108.122
# 2017   89235.316
# 2018   85719.431
# 2019   67821.737
# dtype: float64
# capital costs are 2016   0.000
# 2017   0.000
# 2018   0.000
# 2019   0.000
# dtype: float64
# got to  Parole_Board
# operating costs are budget_fiscal_year
# 2016   2469659.214
# 2017   2491401.058
# 2018   2882493.631
# 2019   2923036.849
# dtype: float64
# pension costs are 2016    902250.328
# 2017   1019011.833
# 2018   1262742.489
# 2019   1245834.195
# dtype: float64
# fringe costs are  year
# 2016   5414354.986
# 2017   5364936.861
# 2018   5081567.929
# 2019   5642100.014
# dtype: float64
# capital costs are 2016        0.000
# 2017        0.000
# 2018        0.000
# 2019   550243.394
# dtype: float64
# got to  CJT
# operating costs are budget_fiscal_year
# 2016   958748.582
# 2017   901405.561
# 2018   856180.589
# 2019   905111.220
# Name: Total Expenditures, dtype: float64
# pension costs are 2016   0.000
# 2017   0.000
# 2018   0.000
# 2019   0.000
# dtype: float64
# fringe costs are  year
# 2016   1441440.267
# 2017   1282351.670
# 2018   1258825.434
# 2019   1338354.472
# dtype: float64
# capital costs are 2016   0.000
# 2017   0.000
# 2018   0.000
# 2019   0.000
# dtype: float64
# got to  Supreme_Judicial_Court
# operating costs are budget_fiscal_year
# 2016   1474339.389
# 2017   1468268.736
# 2018   1619385.766
# 2019   1868860.022
# dtype: float64
# pension costs are 2016   113360.937
# 2017   102329.047
# 2018   108353.093
# 2019   120934.633
# dtype: float64
# fringe costs are  year
# 2016   3374171.669
# 2017   3312690.634
# 2018   3156513.171
# 2019   3219615.739
# dtype: float64
# capital costs are 2016   127279.185
# 2017    31642.122
# 2018    35716.334
# 2019        0.000
# dtype: float64
# got to  Appeals_Court
# operating costs are budget_fiscal_year
# 2016   596851.940
# 2017   578173.888
# 2018   648015.330
# 2019   696127.766
# dtype: float64
# pension costs are 2016   152715.820
# 2017   159183.986
# 2018   178885.570
# 2019   192261.593
# dtype: float64
# fringe costs are  year
# 2016   4466541.881
# 2017   4407082.517
# 2018   4275960.463
# 2019   4252292.439
# dtype: float64
# capital costs are 2016   0.000
# 2017   0.000
# 2018   0.000
# 2019   0.000
# dtype: float64
# got to  Boston PD
# operating costs are 2016    420687492
# 2017    428612013
# 2018    463656887
# 2019    464479137
# 2020            0
# 2021            0
# dtype: int64
# pension costs are 2016    85651521.593
# 2017    85886543.541
# 2018   101811365.031
# 2019   108950264.320
# dtype: object
# fringe costs are  2016   47360497.606
# 2017   50851818.702
# 2018   51431744.131
# 2019   49433405.800
# dtype: object
# capital costs are 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# dtype: int64
# got to  Chelsea PD
# operating costs are 2016    10736088
# 2017    12866419
# 2018    13481240
# 2019    15374194
# 2020    14637357
# dtype: int64
# pension costs are 2016   2804110.759
# 2017   2859943.293
# 2018   2891075.254
# 2019   3133183.585
# 2020           NaN
# dtype: object
# fringe costs are  2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# dtype: int64
# capital costs are 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# dtype: int64
# got to  Revere PD
# operating costs are 2016   10078856.000
# 2017    9705693.000
# 2018   10724700.000
# 2019   10719100.000
# Name: Total Expenditures, dtype: float64
# pension costs are 2016   3491214.104
# 2017   3713579.673
# 2018   3877992.874
# 2019   4156142.635
# dtype: object
# fringe costs are  2016   6401873.418
# 2017   6569579.826
# 2018   6923293.726
# 2019   7895549.663
# dtype: object
# capital costs are 2016   718325.118
# 2017   702314.249
# 2018   601210.529
# 2019    50000.000
# dtype: object
# got to  Winthrop PD

# %%
buggy_agency.operating_costs
# Out:
# 2016   3037686.000
# 2017   3152023.000
# 2018   3500840.000
# 2019   4036935.000
# Name: Total Expenditures, dtype: float64

# %%
buggy_agency.pensions
# Out:
# 2016   912028.782
# 2017   702707.081
# 2018   745260.916
# 2019   778578.451
# dtype: object

# %%
buggy_agency.fringe
# Out:
# 2016    794997.427
# 2017   1188270.591
# 2018   1108502.513
# 2019   1160070.335
# dtype: object

# %%
buggy_agency.capital_expenditures
# Out:
# 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# dtype: int64
