# %% [markdown]
# # Find Correct Employer-Side Contributions
# For the calculation of a pension cost for each agency, we need the yearly employer-side contributions to the Masschusetts Statewide pension fund.
# There are two places a plausable measure of this yearly contribution show up in cthru:
#
# - object class = "(DD) PENSION & INSURANCE RELATED EX"
# - appropriation_name = "(06121020) STATE RETIREMENT BD COMMONWEALTH PENSION"
#
# The appropration name expenditures come out to 1.9ish billion per year, which is close to the number I can find the state budget [here](https://budget.digital.mass.gov/summary/fy20/enacted/independents/treasurer/treasurer?tab=budget-tracking) (look for line 0612-1020).
#
# It is probably true that the object_class expenditures include the teachers's retirement fund, but contributions to that fund total around 2.6 billion per year, so it's more money than both

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sodapy import Socrata
app_token = "2Qa1WiG8G4kj1vGVd2noK7zP0"
client = Socrata("cthru.data.socrata.com", app_token)
client.timeout = 40

# %%
import pandas as pd
pd.set_option("display.max.columns",100)

# %%
big_pensions = pd.DataFrame(client.get("pegc-naaa", where = "object_class = '(DD) PENSION & INSURANCE RELATED EX' AND budget_fiscal_year = 2020",  limit=9999999))

# %%
big_pensions["amount"] = big_pensions["amount"].astype(float)

# %%
big_pensions.groupby("object_code").sum()["amount"].sort_values(ascending=False)
# Out:
# object_code
# (D04) RETIREMENT ALLOWANCE-TEACHERS                                 3.290207e+09
# (D06) EMPLOYEE HEALTH & LIFE INSURANCE                              2.745379e+09
# (D05) RETIREMENT ALLOWANCE-STATE EMPLOYEES                          2.448302e+09
# (D09) FRINGE BENEFIT COST RECOUPMENT                                2.117431e+08
# (D08) HEALTH & WELFARE TRUST FUND                                   6.950973e+07
# (D01) RETIREMENT ALLOWANCES                                         3.618364e+07
# (D90) OPERATING TRANSFER                                            2.586526e+07
# (D12) UNEMPLOYMENT COMPENSATION INSURANCE PREMIUM PAYMENT           1.891380e+07
# (D20) PENSION & INSURANCE RELATED EXPENDITURES                      1.456065e+07
# (D10) SURETY OF EMPLOYEES                                           8.900861e+06
# (D19) UNIVERSAL HEALTH INSURANCE PAYMENTS                           5.902620e+06
# (D24) WORKERS' COMPENSATION  OR (IPP) PAYMENT                       5.053151e+06
# (D15) WORKERS' COMPENSATION CHARGEBACKS                             4.605661e+06
# (D23) GIC HEALTH CARE BUY-OUT                                       1.163874e+06
# (D14) MEDICARE TAX                                                  1.405180e+05
# (D17) MEDICAL EXPENSES                                              2.492620e+04
# (D21) HEALTH INS COSTS OF EMPLOY/LEAVE IN EXCESS OF 1 YR CHGBACK    6.706320e+03
# (D99) LATE PENALTY INTEREST                                         1.889000e+02
# Name: amount, dtype: float64

# %%
D05_code = big_pensions[big_pensions["object_code"].str.contains("(D05)")]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
D05_code["amount"].sum()
# Out:
# 2448301953.73

# %% [markdown]
# Ok this makes sense. This is payouts from pension fund per fiscal year, and the number here roughly matches the numbers at
# http://cthrupensions.mass.gov/#!/year/2020//pay1/explore/0-0-0/retirement_system

# %% [markdown]
# So what we should be using is the appropriation name because we are looking for is employer-side contributions. This all makes sense I feel good about this

# %% [markdown]
# Another important note: the state retirement benefits system seems to have complete data for 2020. This means that the "year" it explains is fiscal year, otherwise the numbers it shows would be incomplete.
# Payroll, however, is by calendar year as the 2020 number at this point is lower.

# %%
good_pensions = pd.DataFrame(client.get("pegc-naaa", where = "appropriation_name = '(06121020) STATE RETIREMENT BD COMMONWEALTH PENSION' and budget_fiscal_year = 2020", limit = 999999))

# %%
good_pensions.head(10)
# Out:
#                 base_id budget_fiscal_year fiscal_period  \
# 0  A0000000002054713691               2020            12
# 1  A0000000002054726179               2020            13
# 2  A0000000002054733200               2020            12
# 3  A0000000002056356853               2020             1
# 4  A0000000002056356883               2020             1
# 5  A0000000002056405746               2020             2
# 6  A0000000002056511539               2020             3
# 7  A0000000002056588958               2020             4
# 8  A0000000002056607246               2020             4
# 9  A0000000002056747986               2020             6
#
#             cabinet_secretariat                           department  \
# 0  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 1  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 2  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 3  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 4  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 5  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 6  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 7  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 8  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
# 9  TREASURER & RECEIVER GENERAL  OFFICE OF THE STATE TREASURER (TRE)
#
#   appropriation_type                                 appropriation_name  \
# 0       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 1       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 2       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 3       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 4       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 5       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 6       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 7       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 8       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
# 9       (3TN) TRUSTS  (06121020) STATE RETIREMENT BD COMMONWEALTH PE...
#
#                           object_class  \
# 0  (DD) PENSION & INSURANCE RELATED EX
# 1  (DD) PENSION & INSURANCE RELATED EX
# 2  (DD) PENSION & INSURANCE RELATED EX
# 3  (DD) PENSION & INSURANCE RELATED EX
# 4  (DD) PENSION & INSURANCE RELATED EX
# 5  (DD) PENSION & INSURANCE RELATED EX
# 6  (DD) PENSION & INSURANCE RELATED EX
# 7  (DD) PENSION & INSURANCE RELATED EX
# 8  (DD) PENSION & INSURANCE RELATED EX
# 9  (DD) PENSION & INSURANCE RELATED EX
#
#                                   object_code           encumbrance_id  \
# 0  (D05) RETIREMENT ALLOWANCE-STATE EMPLOYEES  (UNASSIGNED) UNASSIGNED
# 1  (D05) RETIREMENT ALLOWANCE-STATE EMPLOYEES  (UNASSIGNED) UNASSIGNED
# 2  (D05) RETIREMENT ALLOWANCE-STATE EMPLOYEES  (UNASSIGNED) UNASSIGNED
# 3                 (D01) RETIREMENT ALLOWANCES  (UNASSIGNED) UNASSIGNED
# 4  (D05) RETIREMENT ALLOWANCE-STATE EMPLOYEES  (UNASSIGNED) UNASSIGNED
# 5  (D05) RETIREMENT ALLOWANCE-STATE EMPLOYEES  (UNASSIGNED) UNASSIGNED
# 6                 (D01) RETIREMENT ALLOWANCES  (UNASSIGNED) UNASSIGNED
# 7  (D05) RETIREMENT ALLOWANCE-STATE EMPLOYEES  (UNASSIGNED) UNASSIGNED
# 8                 (D01) RETIREMENT ALLOWANCES  (UNASSIGNED) UNASSIGNED
# 9  (D05) RETIREMENT ALLOWANCE-STATE EMPLOYEES  (UNASSIGNED) UNASSIGNED
#
#      zip_code       amount                              fund fund_code  \
# 0       02108   -185503.59  PENSION RESERVES INVESTMENT FUND      0550
# 1       02108   -309165.26  PENSION RESERVES INVESTMENT FUND      0550
# 2       02108   -111235.34  PENSION RESERVES INVESTMENT FUND      0550
# 3  UNASSIGNED      6598.69  PENSION RESERVES INVESTMENT FUND      0550
# 4  UNASSIGNED   1058556.92  PENSION RESERVES INVESTMENT FUND      0550
# 5  UNASSIGNED  79942404.83  PENSION RESERVES INVESTMENT FUND      0550
# 6  UNASSIGNED    330267.16  PENSION RESERVES INVESTMENT FUND      0550
# 7       02108    -79404.22  PENSION RESERVES INVESTMENT FUND      0550
# 8  UNASSIGNED    328519.74  PENSION RESERVES INVESTMENT FUND      0550
# 9  UNASSIGNED    2283323.4  PENSION RESERVES INVESTMENT FUND      0550
#
#   appropriation_code object department_code  \
# 0           06121020    D05             TRE
# 1           06121020    D05             TRE
# 2           06121020    D05             TRE
# 3           06121020    D01             TRE
# 4           06121020    D05             TRE
# 5           06121020    D05             TRE
# 6           06121020    D01             TRE
# 7           06121020    D05             TRE
# 8           06121020    D01             TRE
# 9           06121020    D05             TRE
#
#                                  vendor   vendor_id            payment_id  \
# 0   INVOICE WARRANT STATE EMPL PENSIONS  UNASSIGNED  07092000000000000017
# 1   INVOICE WARRANT STATE EMPL PENSIONS  UNASSIGNED  07092000000000000018
# 2   INVOICE WARRANT STATE EMPL PENSIONS  UNASSIGNED  07092000000000000016
# 3                 RETIREMENT ALLOWANCES  UNASSIGNED  07241900000000000007
# 4  RETIREMENT ALLOWANCE-STATE EMPLOYEES  UNASSIGNED  07241900000000000010
# 5  RETIREMENT ALLOWANCE-STATE EMPLOYEES  UNASSIGNED  08211900000000000015
# 6                 RETIREMENT ALLOWANCES  UNASSIGNED  09231900000000000029
# 7   INVOICE WARRANT STATE EMPL PENSIONS  UNASSIGNED  10171900000000000135
# 8                 RETIREMENT ALLOWANCES  UNASSIGNED  10241900000000000040
# 9  RETIREMENT ALLOWANCE-STATE EMPLOYEES  UNASSIGNED  12191900000000000060
#
#   payment_method       state        city              create_date  \
# 0     UNASSIGNED          MA      BOSTON  2020-11-05T10:18:24.000
# 1     UNASSIGNED          MA      BOSTON  2020-11-05T10:18:24.000
# 2     UNASSIGNED          MA      BOSTON  2020-11-05T10:18:24.000
# 3          CHECK  UNASSIGNED  UNASSIGNED  2020-11-05T10:18:24.000
# 4          CHECK  UNASSIGNED  UNASSIGNED  2020-11-05T10:18:24.000
# 5          CHECK  UNASSIGNED  UNASSIGNED  2020-11-05T10:18:24.000
# 6          CHECK  UNASSIGNED  UNASSIGNED  2020-11-05T10:18:24.000
# 7     UNASSIGNED          MA      BOSTON  2020-11-05T10:18:24.000
# 8          CHECK  UNASSIGNED  UNASSIGNED  2020-11-05T10:18:24.000
# 9          CHECK  UNASSIGNED  UNASSIGNED  2020-11-05T10:18:24.000
#
#                       date
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  2019-07-29T00:00:00.000
# 4  2019-07-29T00:00:00.000
# 5  2019-08-26T00:00:00.000
# 6  2019-09-25T00:00:00.000
# 7                      NaN
# 8  2019-10-28T00:00:00.000
# 9  2019-12-23T00:00:00.000
